# %%
import pandas as pd

# %%
# pd.Series — это одномерный массив с метками (индексом).
# Создается Series из списка чисел и задаём буквенные метки (index)
# вместо стандартных числовых
my_series=pd.Series([1,2,5,8,1,7,3,1,2,45

],index=["a","b","c","d","e","f","g","h","j","k"])

# %%
my_series
# Out:
# a     1
# b     2
# c     5
# d     8
# e     1
# f     7
# g     3
# h     1
# j     2
# k    45
# dtype: int64

# %%
# Операция my_series > 4 возвращает Series из True/False.
# True там, где значение больше 4, иначе False.
# Это основа фильтрации данных в pandas.
my_series>4
# Out:
# a    False
# b    False
# c     True
# d     True
# e    False
# f     True
# g    False
# h    False
# j    False
# k     True
# dtype: bool

# %%
# Находим все элементы, которые больше 4, и умножаем их на 3.
# Запись my_series[my_series > 4] — это «маска»: выбираются только те элементы,
# где условие истинно. Затем мы перезаписываем их новыми значениями.
my_series[my_series>4]=my_series[my_series>4]*3

# %%
# Получаем значение элемента с меткой 'a'.
# Аналогично словарю: my_series['a'] вернёт число, стоящее под этим ключом.
my_series['a']
# Out:
# np.int64(2)

# %%
my_series

# %%
# pd.DataFrame — двумерная таблица (как Excel-таблица).
# Создаём из словаря: ключи = названия столбцов, значения = данные.
# index задаёт метки строк (вместо 0, 1, 2 будут RU, RZ, BY).
data=pd.DataFrame({
    'contry':["Russia","Kazakhstan","Belarus"],
    'population':[144,17,9.5],
    'capital':["Moscow","Astana","Minsk"]

}
,index=["RU","RZ","BY"]

)

# %%
# Отображаем таблицу целиком.
data
# Out:
#         contry  population capital
# RU      Russia       144.0  Moscow
# RZ  Kazakhstan        17.0  Astana
# BY     Belarus         9.5   Minsk

# %%
# .loc["RU"] возвращает строку с меткой "RU" как Series.
# loc работает именно с МЕТКАМИ (именами), а не с порядковыми номерами.
data.loc["RU"]
# Out:
# contry        Russia
# population     144.0
# capital       Moscow
# Name: RU, dtype: object

# %%
# .iloc[1] возвращает строку с порядковым номером 1 (вторая строка).
# iloc работает с ЧИСЛОВЫМИ позициями: 0 — первая строка, 1 — вторая и т.д.
data.iloc[1]
# Out:
# contry        Kazakhstan
# population          17.0
# capital           Astana
# Name: RZ, dtype: object

# %%
# .index показывает все метки строк DataFrame.
data.index
# Out:
# Index(['RU', 'RZ', 'BY'], dtype='object')

# %%
# Передаём список меток ["RU", "RZ"], чтобы получить сразу две строки.
# Результат — новый DataFrame с двумя строками.
data.loc[["RU","RZ"]]
# Out:
#         contry  population capital
# RU      Russia       144.0  Moscow
# RZ  Kazakhstan        17.0  Astana

# %%
# Первый аргумент loc — какие строки, второй — какой столбец.
# Получаем столицы только для России и Казахстана.
data.loc[["RU","RZ"],"capital"]
# Out:
# RU    Moscow
# RZ    Astana
# Name: capital, dtype: object

# %%
# Создаём новый столбец "size" (площадь, млн км²).
# Список значений должен совпадать по длине с количеством строк.
data["size"]=[17,2.7,0.2]

# %%
data
# Out:
#         contry  population capital  size  population_per_million
# RU      Russia       144.0  Moscow  17.0               12.000000
# RZ  Kazakhstan        17.0  Astana   2.7                1.416667
# BY     Belarus         9.5   Minsk   0.2                0.791667

# %%
# Создаём столбец "population_per_million" как результат деления:
# население / площадь = плотность населения.
# pandas автоматически выполняет поэлементную операцию для каждой строки.
data["population_per_million"]=data.population/data.size

# %%
# .drop() удаляет строки или столбцы.
# axis="columns" (или axis=1) указывает, что удаляем именно столбец.
# inplace=True изменяет исходный DataFrame, а не создаёт копию.
data.drop(["population_per_million"],axis="columns",inplace=True)

# %%
data
# Out:
#         contry  population capital
# RU      Russia       144.0  Moscow
# RZ  Kazakhstan        17.0  Astana
# BY     Belarus         9.5   Minsk

# %%
# Удаляем строку с меткой "BY" (Беларусь).
# По умолчанию axis=0, то есть удаляется строка.
data.drop(["BY"],inplace=True)

# %%
data
# Out:
#      contry  population capital  size
# RU   Russia       144.0  Moscow  17.0
# BY  Belarus         9.5   Minsk   0.2

# %%
# data.population > 10 создаёт булеву маску.
# data[маска] возвращает только те строки, где население > 10.
# .population в конце выбирает только столбец "population".
data[data.population>10].population
# Out:
# RU    144.0
# Name: population, dtype: float64

# %%
# Альтернативный способ получить столбец: data['contry'].
# Возвращает Series со значениями этого столбца.
data['contry']
# Out:
# RU     Russia
# BY    Belarus
# Name: contry, dtype: object

# %%
# Загружаем датасет Titanic из Excel-файла (.xls).
# Результат — DataFrame, где каждая строка = пассажир.
titanic=pd.read_csv("/content/Titanic-Dataset.xls")

# %%
# .head() показывает первые 5 строк.
# Быстрый способ «посмотреть» на данные без вывода всей таблицы (891 строка).
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# .shape возвращает кортеж (число строк, число столбцов).
# Здесь: 891 пассажир и 12 признаков.
titanic.shape
# Out:
# (891, 12)

# %%
# .info() показывает:
#   - количество ненулевых значений в каждом столбце,
#   - тип данных (int64, float64, object),
#   - объём занимаемой памяти.
# Сразу видно, где есть пропуски (например, Age: 714 из 891).
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# .describe() выводит основные статистики для числовых столбцов:
# count, mean, std, min, 25%, 50% (медиана), 75%, max.
# Позволяет быстро оценить распределение данных.
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# .isnull() возвращает DataFrame из True/False:
# True там, где значение отсутствует (NaN).
titanic.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
# .isnull().sum() считает количество True (пропусков) в каждом столбце.
# Видим: Age — 177 пропусков, Cabin — 687, Embarked — 2.
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Cabin имеет 687 пропусков из 891 (~77%), поэтому его проще удалить,
# чем заполнять. axis="columns" — удаляем столбец.
titanic=titanic.drop(["Cabin"],axis="columns")

# %%
# Убеждаемся, что столбец Cabin удалён и осталось только Age и Embarked.
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
# Заменяем пропуски в Age на медианное значение.
# Медиана устойчива к выбросам, поэтому часто предпочтительнее среднего.
# Результат записываем обратно в тот же столбец.
titanic["Age"]=titanic["Age"].fillna(titanic["Age"].median())

# %%
# .mode() возвращает наиболее частое значение.
#  Здесь результат НЕ присваивается обратно — строка не меняет DataFrame.
# Это демонстрация
titanic["Embarked"].fillna(titanic["Embarked"].mode())

# %%
# .value_counts().idxmax() возвращает самое частое значение ('S').
# Присваиваем результат обратно в столбец — теперь пропуски реально заменены.
titanic["Embarked"]=titanic["Embarked"].fillna(titanic["Embarked"].value_counts().idxmax())

# %%
# .groupby() создаёт объект группировки, но сам по себе ничего не считает.
# Это «заготовка»: мы указали, по каким столбцам группировать.
titanic.groupby(["Sex","Survived"])

# %%
# Группируем по полу и статусу выживания, затем считаем количество пассажиров.
# Результат: сколько мужчин/женщин выжило и погибло.
titanic.groupby(["Sex","Survived"])["PassengerId"].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: PassengerId, dtype: int64

# %%
# Аналогично, но группируем по классу каюты (1, 2, 3) и выживанию.
# Видно, что в 3-м классе погибло больше всего
titanic.groupby(["Pclass","Survived"])["PassengerId"].count()
# Out:
# Pclass  Survived
# 1       0            80
#         1           136
# 2       0            97
#         1            87
# 3       0           372
#         1           119
# Name: PassengerId, dtype: int64

# %%
# Экспортируем обработанный DataFrame в Excel-файл.
# index=False — не записывать столбец с индексами (0, 1, 2, ...).
titanic.to_excel("/content/Titanic-Dataset-worked.xlsx",index=False)
